# %%
# !pip install librosa numpy tensorflow soundfile

# %%
#how speech data is prepared

import librosa
import numpy as np

# %%
#load audio

audio_path='sample_speech.wav'
signal,sr=librosa.load(audio_path,sr=None)

print('sampple rate:',sr)
print('audio shape:',signal.shape)
# Out:
# sampple rate: 22050
# audio shape: (32262,)

# %%
#extract MFCC features

mfcc=librosa.feature.mfcc(y=signal,sr=sr,n_mfcc=13)

print('MFCC shape:',mfcc.shape)
# Out:
# MFCC shape: (13, 64)

# %%
#transpose mfcc
mfcc=mfcc.T

#ADD BATCH DIMENSION
X=np.expand_dims(mfcc,axis=0)

print('RNN input shape:',X.shape)
# Out:
# RNN input shape: (1, 64, 13)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense

model=Sequential([
    LSTM(64,input_shape=(X.shape[1],X.shape[2])),
    Dense(10,activation='softmax')  #dummy output classes
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy'
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        19,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,618 (80.54 KB)
#  Trainable params: 20,618 (80.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
prediction=model.predict(X)
print('prediction output',prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# prediction output [[0.08668423 0.07920392 0.09694059 0.07730471 0.06616108 0.2380031
#   0.09243917 0.06246126 0.04039605 0.16040595]]

# %%
#speech to text

# !pip install SpeechRecognition pydub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 57.3 MB/s eta 0:00:00
# ...

# %%
import speech_recognition as sr

#create recognizer object
recognizer=sr.Recognizer()

#load the audio file
audio_file='sample_speech.wav'

with sr.AudioFile(audio_file) as source:
  print('listening to audio....')
  audio_data=recognizer.record(source)

#convert speech to text

try:
  text=recognizer.recognize_google(audio_data)
  print('recognized text:',text)

except sr.UnknownValueError:
  print('could not understand the audio')

except sr.RequestError as e:
  print(f'API error: {e}')
# Out:
# listening to audio....
# recognized text: hello speech recognition
